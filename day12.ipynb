# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')
df.drop(["Name", "PassengerId", "Cabin", "Ticket"], axis = 1, inplace = True)
df.dropna(inplace = True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df_encoded = pd.get_dummies(data = df, columns = ['Sex', "Embarked"], drop_first = True)
df_encoded.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0         0       3  22.0      1      0   7.2500      True       False
# 1         1       1  38.0      1      0  71.2833     False       False
# 2         1       3  26.0      0      0   7.9250     False       False
# 3         1       1  35.0      1      0  53.1000     False       False
# 4         0       3  35.0      0      0   8.0500      True       False
#
#    Embarked_S
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True

# %%
y = df_encoded["Survived"]
X = df_encoded.drop('Survived', axis=1)
pca = PCA(n_components = 2)

# %%
X_transformed = pca.fit_transform(X)

# %%
X.shape
# Out:
# (712, 8)

# %%
X_transformed.shape
# Out:
# (712, 2)

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9992496016522268

# %%
X_transformed
# Out:
# array([[-27.52391788,  -6.89909601],
#        [ 36.94365556,   7.35313619],
#        [-26.7398224 ,  -2.90414289],
#        ...,
#        [ -4.84951617, -10.4709548 ],
#        [ -4.65643277,  -3.47294777],
#        [-26.7494309 ,   3.09932982]])

# %%
for i in range(2, 9):
  pca = PCA(n_components = i)
  pca.fit_transform(X)
  print(sum(pca.explained_variance_ratio_))
# Out:
# 0.999249601652229
# 0.9995673676522464
# 0.9997299773975585
# 0.9998689651608752
# 0.9999364849361978
# 0.9999904699908289
# 1.0
